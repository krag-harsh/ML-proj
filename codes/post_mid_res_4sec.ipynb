# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import cv2
import os
from random import shuffle 
from tqdm import tqdm 
from PIL import Image
from sklearn.metrics import classification_report

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# folder_path="/content/drive/MyDrive/current/ML-project/dataTop/5_image/"
folder_path="/content/drive/MyDrive/ML-project/dataTop5_image_aug2/"
#folder_path='/content/drive/MyDrive/current/ML-project/dataTop5_image_aug/'
na_class=os.listdir(folder_path)
print(na_class)
# Out:
# ['comrav', 'houspa', 'houwre', 'redcro', 'sonspa']

# %%
X=[]
Y=[]
# image_size=226
i=0
for cl in na_class:
  clpath=folder_path+cl
  names=os.listdir(clpath)
  for n in names:
    rpath=clpath+"/"+n
    # img=cv2.imread(rpath,0)
    # img=cv2.resize(img, (image_size, image_size))
    # X.append(img)
    X.append(rpath)
    Y.append(i)
  i+=1
X=np.asarray(X)
Y=np.asarray(Y)

# %%
print(len(Y))
# Out:
# 3831

# %%
from sklearn.model_selection import train_test_split
# x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.1, random_state=12)

x_train, X_temp, y_train, Y_temp = train_test_split(X, Y, test_size=0.2, random_state=12)
x_val, x_test, y_val, y_test = train_test_split(X_temp, Y_temp, test_size=0.5, random_state=12)

print(len(x_train), len(x_val), len(x_test))
# Out:
# 3064 383 384

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import torchvision.models as models

transform_train = transforms.Compose([
    transforms.Resize((224,224)),
    # transforms.RandomCrop(224, padding=4),
    transforms.RandomVerticalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))
])

transform_test = transforms.Compose([
    transforms.Resize((224,224)),
    transforms.ToTensor(),
    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))
])

# %%
from torch.utils.data import Dataset, DataLoader, ConcatDataset
from PIL import Image

class cDataset(Dataset):
    def __init__(self, root, labels, transform=None):
      self.root = root
      self.labels = labels
      self.transform = transform
    
    def __len__(self):
      return len(self.labels)
        
    def __getitem__(self, index):
      path = self.root[index]
      label = self.labels[index]
      with open(path, 'rb') as f:
        sample = Image.open(f).convert('RGB')
        # sample = Image.open(f).convert('L')
      if self.transform is not None:
        sample = self.transform(sample)
      return sample, label

# %%
print(x_train[0])
# Out:
# /content/drive/MyDrive/ML-project/dataTop5_image_aug2/redcro/XC382983.jpg

# %%
bs=256
trainset = cDataset(x_train, y_train, transform=transform_train)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=bs, shuffle=True,drop_last = True)

valset = cDataset(x_test, y_test, transform=transform_test)
valloader = torch.utils.data.DataLoader(valset, batch_size=bs)

testset = cDataset(x_test, y_test, transform=transform_test)
testloader = torch.utils.data.DataLoader(testset, batch_size=bs)

# %%
print(len(trainset))
n_total_steps = len(trainloader)
print(n_total_steps)
# Out:
# 3064
# 11

# %%
for b_idx, (inputs, targets) in enumerate(trainloader):
  print(b_idx)
  # print(inputs)
  print(targets)
  break
# Out:
# 0
# tensor([0, 3, 4, 3, 3, 3, 3, 1, 1, 4, 0, 1, 2, 0, 1, 0, 3, 3, 3, 2, 2, 4, 1, 4,
#         3, 2, 0, 3, 3, 3, 2, 3, 3, 3, 0, 3, 3, 1, 1, 2, 3, 0, 2, 3, 0, 0, 0, 2,
#         0, 3, 0, 4, 3, 3, 4, 1, 3, 3, 3, 2, 2, 1, 0, 3, 0, 0, 3, 2, 4, 3, 3, 0,
#         1, 0, 0, 3, 3, 4, 0, 0, 3, 3, 0, 1, 2, 3, 3, 2, 3, 1, 2, 1, 1, 3, 2, 2,
#         1, 1, 4, 4, 3, 3, 2, 3, 4, 3, 1, 3, 3, 0, 3, 3, 3, 0, 3, 4, 4, 3, 1, 1,
#         0, 0, 4, 4, 3, 1, 2, 1, 3, 1, 3, 3, 1, 3, 3, 4, 1, 2, 3, 3, 0, 2, 0, 1,
#         3, 1, 1, 1, 1, 3, 4, 0, 1, 2, 1, 4, 1, 2, 1, 3, 3, 4, 0, 3, 3, 1, 3, 4,
#         0, 3, 0, 1, 1, 1, 2, 3, 2, 3, 0, 2, 3, 3, 1, 4, 3, 3, 1, 1, 4, 1, 3, 3,
#         2, 0, 4, 4, 2, 1, 3, 1, 3, 3, 1, 0, 3, 3, 0, 0, 3, 3, 2, 0, 1, 0, 1, 0,
#         0, 3, 3, 2, 1, 3, 0, 2, 0, 4, 1, 2, 2, 2, 0, 1, 3, 3, 3, 2, 3, 3, 3, 3,
#         1, 0, 3, 0, 0, 3, 0, 3, 3, 3, 1, 3, 0, 4, 1, 1])

# %%
torch.cuda.is_available()
# Out:
# True

# %%
# https://towardsdatascience.com/how-to-train-an-image-classifier-in-pytorch-and-use-it-to-perform-basic-inference-on-single-images-99465a1e9bf5

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = models.resnet50(pretrained=True)
# model = models.resnet34(pretrained=True)
# 18
# try with efficientNetB3 (trained on imagenet)
# print(model)

# %%
from torch import nn
from torch import optim
for param in model.parameters():
    param.requires_grad = False
    
model.fc = nn.Sequential(nn.Linear(2048, 512),
                                 nn.ReLU(),
                                 nn.Dropout(0.5),
                                 nn.Linear(512, 5),
                                 nn.LogSoftmax(dim=1))
criterion = nn.NLLLoss()
optimizer = optim.Adam(model.fc.parameters(), lr=0.003)
model.to(device)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=512, out_features=5, bias=True)
#     (4): LogSoftmax(dim=1)
#   )
# )

# %%
epochs = 50
steps = 0
running_loss = 0
print_every = 10
val_acc_best=0
# print_every = 20
# print_every = 
model_best=model
train_losses, test_losses = [], []
for epoch in range(epochs):
    for inputs, labels in trainloader:
        steps += 1
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        logps = model.forward(inputs)
        loss = criterion(logps, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        print(f"Step {steps} Epoch {epoch+1}/{epochs}.. ")
        if steps % print_every == 0:
            test_loss = 0
            accuracy = 0
            model.eval()
            with torch.no_grad():
                for inputs, labels in valloader:
                    inputs, labels = inputs.to(device),labels.to(device)
                    logps = model.forward(inputs)
                    batch_loss = criterion(logps, labels)
                    test_loss += batch_loss.item()
                    
                    ps = torch.exp(logps)
                    top_p, top_class = ps.topk(1, dim=1)
                    equals =top_class == labels.view(*top_class.shape)
                    accuracy +=torch.mean(equals.type(torch.FloatTensor)).item()
            train_losses.append(running_loss/len(trainloader))
            test_losses.append(test_loss/len(valloader))
            cur_val_acc=accuracy/len(valloader)
            if(cur_val_acc>val_acc_best):
              cur_val_acc=val_acc_best
              model_best=model               
            print(f"Epoch {epoch+1}/{epochs}.. "
                  f"Train loss: {running_loss/print_every:.3f}.. "
                  f"Test loss: {test_loss/len(valloader):.3f}.. "
                  f"Test accuracy: {accuracy/len(valloader):.3f}")
            running_loss = 0
            model.train()
            torch.save(model, 'aerialmodel0.pth')
# torch.save(model, 'aerialmodel.pth')
# Out:
# Step 1 Epoch 1/50..
# Step 2 Epoch 1/50..
# Step 3 Epoch 1/50..
# Step 4 Epoch 1/50..
# Step 5 Epoch 1/50..
# Step 6 Epoch 1/50..
# Step 7 Epoch 1/50..
# Step 8 Epoch 1/50..
# Step 9 Epoch 1/50..
# Step 10 Epoch 1/50..
# Epoch 1/50.. Train loss: 3.122.. Test loss: 1.579.. Test accuracy: 0.396
# Step 11 Epoch 1/50..
# Step 12 Epoch 2/50..
# Step 13 Epoch 2/50..
# Step 14 Epoch 2/50..
# Step 15 Epoch 2/50..
# Step 16 Epoch 2/50..
# Step 17 Epoch 2/50..
# Step 18 Epoch 2/50..
# Step 19 Epoch 2/50..
# Step 20 Epoch 2/50..
# Epoch 2/50.. Train loss: 1.524.. Test loss: 1.431.. Test accuracy: 0.400
# Step 21 Epoch 2/50..
# Step 22 Epoch 2/50..
# Step 23 Epoch 3/50..
# Step 24 Epoch 3/50..
# Step 25 Epoch 3/50..
# Step 26 Epoch 3/50..
# Step 27 Epoch 3/50..
# Step 28 Epoch 3/50..
# Step 29 Epoch 3/50..
# Step 30 Epoch 3/50..
# Epoch 3/50.. Train loss: 1.439.. Test loss: 1.363.. Test accuracy: 0.389
# Step 31 Epoch 3/50..
# Step 32 Epoch 3/50..
# Step 33 Epoch 3/50..
# Step 34 Epoch 4/50..
# Step 35 Epoch 4/50..
# Step 36 Epoch 4/50..
# Step 37 Epoch 4/50..
# Step 38 Epoch 4/50..
# Step 39 Epoch 4/50..
# Step 40 Epoch 4/50..
# Epoch 4/50.. Train loss: 1.357.. Test loss: 1.316.. Test accuracy: 0.455
# Step 41 Epoch 4/50..
# Step 42 Epoch 4/50..
# Step 43 Epoch 4/50..
# Step 44 Epoch 4/50..
# Step 45 Epoch 5/50..
# Step 46 Epoch 5/50..
# Step 47 Epoch 5/50..
# Step 48 Epoch 5/50..
# Step 49 Epoch 5/50..
# Step 50 Epoch 5/50..
# Epoch 5/50.. Train loss: 1.332.. Test loss: 1.244.. Test accuracy: 0.531
# Step 51 Epoch 5/50..
# Step 52 Epoch 5/50..
# Step 53 Epoch 5/50..
# Step 54 Epoch 5/50..
# Step 55 Epoch 5/50..
# Step 56 Epoch 6/50..
# Step 57 Epoch 6/50..
# Step 58 Epoch 6/50..
# Step 59 Epoch 6/50..
# Step 60 Epoch 6/50..
# Epoch 6/50.. Train loss: 1.262.. Test loss: 1.168.. Test accuracy: 0.584
# Step 61 Epoch 6/50..
# Step 62 Epoch 6/50..
# Step 63 Epoch 6/50..
# Step 64 Epoch 6/50..
# Step 65 Epoch 6/50..
# Step 66 Epoch 6/50..
# Step 67 Epoch 7/50..
# Step 68 Epoch 7/50..
# Step 69 Epoch 7/50..
# Step 70 Epoch 7/50..
# Epoch 7/50.. Train loss: 1.219.. Test loss: 1.134.. Test accuracy: 0.607
# Step 71 Epoch 7/50..
# Step 72 Epoch 7/50..
# Step 73 Epoch 7/50..
# Step 74 Epoch 7/50..
# Step 75 Epoch 7/50..
# Step 76 Epoch 7/50..
# Step 77 Epoch 7/50..
# Step 78 Epoch 8/50..
# Step 79 Epoch 8/50..
# Step 80 Epoch 8/50..
# Epoch 8/50.. Train loss: 1.167.. Test loss: 1.089.. Test accuracy: 0.598
# Step 81 Epoch 8/50..
# Step 82 Epoch 8/50..
# Step 83 Epoch 8/50..
# Step 84 Epoch 8/50..
# Step 85 Epoch 8/50..
# Step 86 Epoch 8/50..
# Step 87 Epoch 8/50..
# Step 88 Epoch 8/50..
# Step 89 Epoch 9/50..
# Step 90 Epoch 9/50..
# Epoch 9/50.. Train loss: 1.150.. Test loss: 1.071.. Test accuracy: 0.623
# Step 91 Epoch 9/50..
# Step 92 Epoch 9/50..
# Step 93 Epoch 9/50..
# Step 94 Epoch 9/50..
# Step 95 Epoch 9/50..
# Step 96 Epoch 9/50..
# Step 97 Epoch 9/50..
# Step 98 Epoch 9/50..
# Step 99 Epoch 9/50..
# Step 100 Epoch 10/50..
# Epoch 10/50.. Train loss: 1.118.. Test loss: 1.030.. Test accuracy: 0.631
# Step 101 Epoch 10/50..
# Step 102 Epoch 10/50..
# Step 103 Epoch 10/50..
# Step 104 Epoch 10/50..
# Step 105 Epoch 10/50..
# Step 106 Epoch 10/50..
# Step 107 Epoch 10/50..
# Step 108 Epoch 10/50..
# Step 109 Epoch 10/50..
# Step 110 Epoch 10/50..
# Epoch 10/50.. Train loss: 1.117.. Test loss: 1.040.. Test accuracy: 0.645
# Step 111 Epoch 11/50..
# Step 112 Epoch 11/50..
# Step 113 Epoch 11/50..
# Step 114 Epoch 11/50..
# Step 115 Epoch 11/50..
# Step 116 Epoch 11/50..
# Step 117 Epoch 11/50..
# Step 118 Epoch 11/50..
# Step 119 Epoch 11/50..
# Step 120 Epoch 11/50..
# Epoch 11/50.. Train loss: 1.079.. Test loss: 0.986.. Test accuracy: 0.615
# Step 121 Epoch 11/50..
# Step 122 Epoch 12/50..
# Step 123 Epoch 12/50..
# Step 124 Epoch 12/50..
# Step 125 Epoch 12/50..
# Step 126 Epoch 12/50..
# Step 127 Epoch 12/50..
# Step 128 Epoch 12/50..
# Step 129 Epoch 12/50..
# Step 130 Epoch 12/50..
# Epoch 12/50.. Train loss: 1.075.. Test loss: 0.947.. Test accuracy: 0.654
# Step 131 Epoch 12/50..
# Step 132 Epoch 12/50..
# Step 133 Epoch 13/50..
# Step 134 Epoch 13/50..
# Step 135 Epoch 13/50..
# Step 136 Epoch 13/50..
# Step 137 Epoch 13/50..
# Step 138 Epoch 13/50..
# Step 139 Epoch 13/50..
# Step 140 Epoch 13/50..
# Epoch 13/50.. Train loss: 1.011.. Test loss: 0.949.. Test accuracy: 0.652
# Step 141 Epoch 13/50..
# Step 142 Epoch 13/50..
# Step 143 Epoch 13/50..
# Step 144 Epoch 14/50..
# Step 145 Epoch 14/50..
# Step 146 Epoch 14/50..
# Step 147 Epoch 14/50..
# Step 148 Epoch 14/50..
# Step 149 Epoch 14/50..
# Step 150 Epoch 14/50..
# Epoch 14/50.. Train loss: 1.048.. Test loss: 0.965.. Test accuracy: 0.621
# Step 151 Epoch 14/50..
# Step 152 Epoch 14/50..
# Step 153 Epoch 14/50..
# Step 154 Epoch 14/50..
# Step 155 Epoch 15/50..
# Step 156 Epoch 15/50..
# Step 157 Epoch 15/50..
# Step 158 Epoch 15/50..
# Step 159 Epoch 15/50..
# Step 160 Epoch 15/50..
# Epoch 15/50.. Train loss: 1.016.. Test loss: 0.951.. Test accuracy: 0.660
# Step 161 Epoch 15/50..
# Step 162 Epoch 15/50..
# Step 163 Epoch 15/50..
# Step 164 Epoch 15/50..
# Step 165 Epoch 15/50..
# Step 166 Epoch 16/50..
# Step 167 Epoch 16/50..
# Step 168 Epoch 16/50..
# Step 169 Epoch 16/50..
# Step 170 Epoch 16/50..
# Epoch 16/50.. Train loss: 1.019.. Test loss: 0.920.. Test accuracy: 0.684
# Step 171 Epoch 16/50..
# Step 172 Epoch 16/50..
# Step 173 Epoch 16/50..
# Step 174 Epoch 16/50..
# Step 175 Epoch 16/50..
# Step 176 Epoch 16/50..
# Step 177 Epoch 17/50..
# Step 178 Epoch 17/50..
# Step 179 Epoch 17/50..
# Step 180 Epoch 17/50..
# Epoch 17/50.. Train loss: 1.033.. Test loss: 0.978.. Test accuracy: 0.658
# Step 181 Epoch 17/50..
# Step 182 Epoch 17/50..
# Step 183 Epoch 17/50..
# Step 184 Epoch 17/50..
# Step 185 Epoch 17/50..
# Step 186 Epoch 17/50..
# Step 187 Epoch 17/50..
# Step 188 Epoch 18/50..
# Step 189 Epoch 18/50..
# Step 190 Epoch 18/50..
# Epoch 18/50.. Train loss: 1.016.. Test loss: 0.926.. Test accuracy: 0.656
# Step 191 Epoch 18/50..
# Step 192 Epoch 18/50..
# Step 193 Epoch 18/50..
# Step 194 Epoch 18/50..
# Step 195 Epoch 18/50..
# Step 196 Epoch 18/50..
# Step 197 Epoch 18/50..
# Step 198 Epoch 18/50..
# Step 199 Epoch 19/50..
# Step 200 Epoch 19/50..
# Epoch 19/50.. Train loss: 0.990.. Test loss: 0.906.. Test accuracy: 0.672
# Step 201 Epoch 19/50..
# Step 202 Epoch 19/50..
# Step 203 Epoch 19/50..
# Step 204 Epoch 19/50..
# Step 205 Epoch 19/50..
# Step 206 Epoch 19/50..
# Step 207 Epoch 19/50..
# Step 208 Epoch 19/50..
# Step 209 Epoch 19/50..
# Step 210 Epoch 20/50..
# Epoch 20/50.. Train loss: 1.011.. Test loss: 0.955.. Test accuracy: 0.652
# Step 211 Epoch 20/50..
# Step 212 Epoch 20/50..
# Step 213 Epoch 20/50..
# Step 214 Epoch 20/50..
# Step 215 Epoch 20/50..
# Step 216 Epoch 20/50..
# Step 217 Epoch 20/50..
# Step 218 Epoch 20/50..
# Step 219 Epoch 20/50..
# Step 220 Epoch 20/50..
# Epoch 20/50.. Train loss: 0.999.. Test loss: 0.899.. Test accuracy: 0.670
# Step 221 Epoch 21/50..
# Step 222 Epoch 21/50..
# Step 223 Epoch 21/50..
# Step 224 Epoch 21/50..
# Step 225 Epoch 21/50..
# Step 226 Epoch 21/50..
# Step 227 Epoch 21/50..
# Step 228 Epoch 21/50..
# Step 229 Epoch 21/50..
# Step 230 Epoch 21/50..
# Epoch 21/50.. Train loss: 0.969.. Test loss: 0.896.. Test accuracy: 0.691
# Step 231 Epoch 21/50..
# Step 232 Epoch 22/50..
# Step 233 Epoch 22/50..
# Step 234 Epoch 22/50..
# Step 235 Epoch 22/50..
# Step 236 Epoch 22/50..
# Step 237 Epoch 22/50..
# Step 238 Epoch 22/50..
# Step 239 Epoch 22/50..
# Step 240 Epoch 22/50..
# Epoch 22/50.. Train loss: 0.974.. Test loss: 0.935.. Test accuracy: 0.641
# Step 241 Epoch 22/50..
# Step 242 Epoch 22/50..
# Step 243 Epoch 23/50..
# Step 244 Epoch 23/50..
# Step 245 Epoch 23/50..
# Step 246 Epoch 23/50..
# Step 247 Epoch 23/50..
# Step 248 Epoch 23/50..
# Step 249 Epoch 23/50..
# Step 250 Epoch 23/50..
# Epoch 23/50.. Train loss: 0.968.. Test loss: 0.880.. Test accuracy: 0.684
# Step 251 Epoch 23/50..
# Step 252 Epoch 23/50..
# Step 253 Epoch 23/50..
# Step 254 Epoch 24/50..
# Step 255 Epoch 24/50..
# Step 256 Epoch 24/50..
# Step 257 Epoch 24/50..
# Step 258 Epoch 24/50..
# Step 259 Epoch 24/50..
# Step 260 Epoch 24/50..
# Epoch 24/50.. Train loss: 0.946.. Test loss: 0.879.. Test accuracy: 0.705
# Step 261 Epoch 24/50..
# Step 262 Epoch 24/50..
# Step 263 Epoch 24/50..
# Step 264 Epoch 24/50..
# Step 265 Epoch 25/50..
# Step 266 Epoch 25/50..
# Step 267 Epoch 25/50..
# Step 268 Epoch 25/50..
# Step 269 Epoch 25/50..
# Step 270 Epoch 25/50..
# Epoch 25/50.. Train loss: 0.946.. Test loss: 0.869.. Test accuracy: 0.713
# Step 271 Epoch 25/50..
# Step 272 Epoch 25/50..
# Step 273 Epoch 25/50..
# Step 274 Epoch 25/50..
# Step 275 Epoch 25/50..
# Step 276 Epoch 26/50..
# Step 277 Epoch 26/50..
# Step 278 Epoch 26/50..
# Step 279 Epoch 26/50..
# Step 280 Epoch 26/50..
# Epoch 26/50.. Train loss: 0.917.. Test loss: 0.870.. Test accuracy: 0.699
# Step 281 Epoch 26/50..
# Step 282 Epoch 26/50..
# Step 283 Epoch 26/50..
# Step 284 Epoch 26/50..
# Step 285 Epoch 26/50..
# Step 286 Epoch 26/50..
# Step 287 Epoch 27/50..
# Step 288 Epoch 27/50..
# Step 289 Epoch 27/50..
# Step 290 Epoch 27/50..
# Epoch 27/50.. Train loss: 0.943.. Test loss: 0.888.. Test accuracy: 0.691
# Step 291 Epoch 27/50..
# Step 292 Epoch 27/50..
# Step 293 Epoch 27/50..
# Step 294 Epoch 27/50..
# Step 295 Epoch 27/50..
# Step 296 Epoch 27/50..
# Step 297 Epoch 27/50..
# Step 298 Epoch 28/50..
# Step 299 Epoch 28/50..
# Step 300 Epoch 28/50..
# Epoch 28/50.. Train loss: 0.920.. Test loss: 0.881.. Test accuracy: 0.713
# Step 301 Epoch 28/50..
# Step 302 Epoch 28/50..
# Step 303 Epoch 28/50..
# Step 304 Epoch 28/50..
# Step 305 Epoch 28/50..
# Step 306 Epoch 28/50..
# Step 307 Epoch 28/50..
# Step 308 Epoch 28/50..
# Step 309 Epoch 29/50..
# Step 310 Epoch 29/50..
# Epoch 29/50.. Train loss: 0.949.. Test loss: 0.883.. Test accuracy: 0.664
# Step 311 Epoch 29/50..
# Step 312 Epoch 29/50..
# Step 313 Epoch 29/50..
# Step 314 Epoch 29/50..
# Step 315 Epoch 29/50..
# Step 316 Epoch 29/50..
# Step 317 Epoch 29/50..
# Step 318 Epoch 29/50..
# Step 319 Epoch 29/50..
# Step 320 Epoch 30/50..
# Epoch 30/50.. Train loss: 0.980.. Test loss: 0.868.. Test accuracy: 0.707
# Step 321 Epoch 30/50..
# Step 322 Epoch 30/50..
# Step 323 Epoch 30/50..
# Step 324 Epoch 30/50..
# Step 325 Epoch 30/50..
# Step 326 Epoch 30/50..
# Step 327 Epoch 30/50..
# Step 328 Epoch 30/50..
# Step 329 Epoch 30/50..
# Step 330 Epoch 30/50..
# Epoch 30/50.. Train loss: 0.939.. Test loss: 0.872.. Test accuracy: 0.711
# Step 331 Epoch 31/50..
# Step 332 Epoch 31/50..
# Step 333 Epoch 31/50..
# Step 334 Epoch 31/50..
# Step 335 Epoch 31/50..
# Step 336 Epoch 31/50..
# Step 337 Epoch 31/50..
# Step 338 Epoch 31/50..
# Step 339 Epoch 31/50..
# Step 340 Epoch 31/50..
# Epoch 31/50.. Train loss: 0.915.. Test loss: 0.885.. Test accuracy: 0.709
# Step 341 Epoch 31/50..
# Step 342 Epoch 32/50..
# Step 343 Epoch 32/50..
# Step 344 Epoch 32/50..
# Step 345 Epoch 32/50..
# Step 346 Epoch 32/50..
# Step 347 Epoch 32/50..
# Step 348 Epoch 32/50..
# Step 349 Epoch 32/50..
# Step 350 Epoch 32/50..
# Epoch 32/50.. Train loss: 0.921.. Test loss: 0.878.. Test accuracy: 0.695
# Step 351 Epoch 32/50..
# Step 352 Epoch 32/50..
# Step 353 Epoch 33/50..
# Step 354 Epoch 33/50..
# Step 355 Epoch 33/50..
# Step 356 Epoch 33/50..
# Step 357 Epoch 33/50..
# Step 358 Epoch 33/50..
# Step 359 Epoch 33/50..
# Step 360 Epoch 33/50..
# Epoch 33/50.. Train loss: 0.941.. Test loss: 0.941.. Test accuracy: 0.615
# Step 361 Epoch 33/50..
# Step 362 Epoch 33/50..
# Step 363 Epoch 33/50..
# Step 364 Epoch 34/50..
# Step 365 Epoch 34/50..
# Step 366 Epoch 34/50..
# Step 367 Epoch 34/50..
# Step 368 Epoch 34/50..
# Step 369 Epoch 34/50..
# Step 370 Epoch 34/50..
# Epoch 34/50.. Train loss: 0.977.. Test loss: 0.852.. Test accuracy: 0.668
# Step 371 Epoch 34/50..
# Step 372 Epoch 34/50..
# Step 373 Epoch 34/50..
# Step 374 Epoch 34/50..
# Step 375 Epoch 35/50..
# Step 376 Epoch 35/50..
# Step 377 Epoch 35/50..
# Step 378 Epoch 35/50..
# Step 379 Epoch 35/50..
# Step 380 Epoch 35/50..
# Epoch 35/50.. Train loss: 0.963.. Test loss: 0.908.. Test accuracy: 0.664
# Step 381 Epoch 35/50..
# Step 382 Epoch 35/50..
# Step 383 Epoch 35/50..
# Step 384 Epoch 35/50..
# Step 385 Epoch 35/50..
# Step 386 Epoch 36/50..
# Step 387 Epoch 36/50..
# Step 388 Epoch 36/50..
# Step 389 Epoch 36/50..
# Step 390 Epoch 36/50..
# Epoch 36/50.. Train loss: 0.963.. Test loss: 0.887.. Test accuracy: 0.680
# Step 391 Epoch 36/50..
# Step 392 Epoch 36/50..
# Step 393 Epoch 36/50..
# Step 394 Epoch 36/50..
# Step 395 Epoch 36/50..
# Step 396 Epoch 36/50..
# Step 397 Epoch 37/50..
# Step 398 Epoch 37/50..
# Step 399 Epoch 37/50..
# Step 400 Epoch 37/50..
# Epoch 37/50.. Train loss: 0.945.. Test loss: 0.858.. Test accuracy: 0.682
# Step 401 Epoch 37/50..
# Step 402 Epoch 37/50..
# Step 403 Epoch 37/50..
# Step 404 Epoch 37/50..
# Step 405 Epoch 37/50..
# Step 406 Epoch 37/50..
# Step 407 Epoch 37/50..
# Step 408 Epoch 38/50..
# Step 409 Epoch 38/50..
# Step 410 Epoch 38/50..
# Epoch 38/50.. Train loss: 0.953.. Test loss: 0.858.. Test accuracy: 0.695
# Step 411 Epoch 38/50..
# Step 412 Epoch 38/50..
# Step 413 Epoch 38/50..
# Step 414 Epoch 38/50..
# Step 415 Epoch 38/50..
# Step 416 Epoch 38/50..
# Step 417 Epoch 38/50..
# Step 418 Epoch 38/50..
# Step 419 Epoch 39/50..
# Step 420 Epoch 39/50..
# Epoch 39/50.. Train loss: 0.930.. Test loss: 0.883.. Test accuracy: 0.686
# Step 421 Epoch 39/50..
# Step 422 Epoch 39/50..
# Step 423 Epoch 39/50..
# Step 424 Epoch 39/50..
# Step 425 Epoch 39/50..
# Step 426 Epoch 39/50..
# Step 427 Epoch 39/50..
# Step 428 Epoch 39/50..
# Step 429 Epoch 39/50..
# Step 430 Epoch 40/50..
# Epoch 40/50.. Train loss: 0.958.. Test loss: 0.874.. Test accuracy: 0.662
# Step 431 Epoch 40/50..
# Step 432 Epoch 40/50..
# Step 433 Epoch 40/50..
# Step 434 Epoch 40/50..
# Step 435 Epoch 40/50..
# Step 436 Epoch 40/50..
# Step 437 Epoch 40/50..
# Step 438 Epoch 40/50..
# Step 439 Epoch 40/50..
# Step 440 Epoch 40/50..
# Epoch 40/50.. Train loss: 0.931.. Test loss: 0.863.. Test accuracy: 0.705
# Step 441 Epoch 41/50..
# Step 442 Epoch 41/50..
# Step 443 Epoch 41/50..
# Step 444 Epoch 41/50..
# Step 445 Epoch 41/50..
# Step 446 Epoch 41/50..
# Step 447 Epoch 41/50..
# Step 448 Epoch 41/50..
# Step 449 Epoch 41/50..
# Step 450 Epoch 41/50..
# Epoch 41/50.. Train loss: 0.944.. Test loss: 0.854.. Test accuracy: 0.691
# Step 451 Epoch 41/50..
# Step 452 Epoch 42/50..
# Step 453 Epoch 42/50..
# Step 454 Epoch 42/50..
# Step 455 Epoch 42/50..
# Step 456 Epoch 42/50..
# Step 457 Epoch 42/50..
# Step 458 Epoch 42/50..
# Step 459 Epoch 42/50..
# Step 460 Epoch 42/50..
# Epoch 42/50.. Train loss: 0.910.. Test loss: 0.892.. Test accuracy: 0.658
# Step 461 Epoch 42/50..
# Step 462 Epoch 42/50..
# Step 463 Epoch 43/50..
# Step 464 Epoch 43/50..
# Step 465 Epoch 43/50..
# Step 466 Epoch 43/50..
# Step 467 Epoch 43/50..
# Step 468 Epoch 43/50..
# Step 469 Epoch 43/50..
# Step 470 Epoch 43/50..
# Epoch 43/50.. Train loss: 0.884.. Test loss: 0.869.. Test accuracy: 0.668
# Step 471 Epoch 43/50..
# Step 472 Epoch 43/50..
# Step 473 Epoch 43/50..
# Step 474 Epoch 44/50..
# Step 475 Epoch 44/50..
# Step 476 Epoch 44/50..
# Step 477 Epoch 44/50..
# Step 478 Epoch 44/50..
# Step 479 Epoch 44/50..
# Step 480 Epoch 44/50..
# Epoch 44/50.. Train loss: 0.917.. Test loss: 0.871.. Test accuracy: 0.676
# Step 481 Epoch 44/50..
# Step 482 Epoch 44/50..
# Step 483 Epoch 44/50..
# Step 484 Epoch 44/50..
# Step 485 Epoch 45/50..
# Step 486 Epoch 45/50..
# Step 487 Epoch 45/50..
# Step 488 Epoch 45/50..
# Step 489 Epoch 45/50..
# Step 490 Epoch 45/50..
# Epoch 45/50.. Train loss: 0.914.. Test loss: 0.843.. Test accuracy: 0.699
# Step 491 Epoch 45/50..
# Step 492 Epoch 45/50..
# Step 493 Epoch 45/50..
# Step 494 Epoch 45/50..
# Step 495 Epoch 45/50..
# Step 496 Epoch 46/50..
# Step 497 Epoch 46/50..
# Step 498 Epoch 46/50..
# Step 499 Epoch 46/50..
# Step 500 Epoch 46/50..
# Epoch 46/50.. Train loss: 0.884.. Test loss: 0.868.. Test accuracy: 0.674
# Step 501 Epoch 46/50..
# Step 502 Epoch 46/50..
# Step 503 Epoch 46/50..
# Step 504 Epoch 46/50..
# Step 505 Epoch 46/50..
# Step 506 Epoch 46/50..
# Step 507 Epoch 47/50..
# Step 508 Epoch 47/50..
# Step 509 Epoch 47/50..
# Step 510 Epoch 47/50..
# Epoch 47/50.. Train loss: 0.942.. Test loss: 0.889.. Test accuracy: 0.643
# Step 511 Epoch 47/50..
# Step 512 Epoch 47/50..
# Step 513 Epoch 47/50..
# Step 514 Epoch 47/50..
# Step 515 Epoch 47/50..
# Step 516 Epoch 47/50..
# Step 517 Epoch 47/50..
# Step 518 Epoch 48/50..
# Step 519 Epoch 48/50..
# Step 520 Epoch 48/50..
# Epoch 48/50.. Train loss: 0.916.. Test loss: 0.859.. Test accuracy: 0.695
# Step 521 Epoch 48/50..
# Step 522 Epoch 48/50..
# Step 523 Epoch 48/50..
# Step 524 Epoch 48/50..
# Step 525 Epoch 48/50..
# Step 526 Epoch 48/50..
# Step 527 Epoch 48/50..
# Step 528 Epoch 48/50..
# Step 529 Epoch 49/50..
# Step 530 Epoch 49/50..
# Epoch 49/50.. Train loss: 0.918.. Test loss: 0.878.. Test accuracy: 0.680
# Step 531 Epoch 49/50..
# Step 532 Epoch 49/50..
# Step 533 Epoch 49/50..
# Step 534 Epoch 49/50..
# Step 535 Epoch 49/50..
# Step 536 Epoch 49/50..
# Step 537 Epoch 49/50..
# Step 538 Epoch 49/50..
# Step 539 Epoch 49/50..
# Step 540 Epoch 50/50..
# Epoch 50/50.. Train loss: 0.906.. Test loss: 0.868.. Test accuracy: 0.689
# Step 541 Epoch 50/50..
# Step 542 Epoch 50/50..
# Step 543 Epoch 50/50..
# Step 544 Epoch 50/50..
# Step 545 Epoch 50/50..
# Step 546 Epoch 50/50..
# Step 547 Epoch 50/50..
# Step 548 Epoch 50/50..
# Step 549 Epoch 50/50..
# Step 550 Epoch 50/50..
# Epoch 50/50.. Train loss: 0.881.. Test loss: 0.889.. Test accuracy: 0.664

# %%
import pickle
m_p="/content/drive/MyDrive/ML-project/checkpoints/res_net_4sec.pkl"
f=open(m_p, "wb")
pickle.dump(model,f)  # saving weights
f.close()

# %%
plt.plot(train_losses, label='Training loss')
plt.plot(test_losses, label='Validation loss')
plt.legend(frameon=False)
plt.show()

# %% [markdown]
# Evaluation

# %%
import pickle
pa_m="/content/drive/MyDrive/ML-project/checkpoints/res_net_4sec.pkl"
model=pickle.load(open(pa_m, "rb"))

# %%
n_c=5 # number of classes is 
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
cm=torch.zeros(n_c, n_c)  # creating confusion matrix
model.eval()  # setting model for evaluation
nsamples,ncorrect=0,0
for i,(inputs,labels) in enumerate(testloader):  # using the test data
  inputs=inputs.to(device)
  labels=labels.to(device)
  outputs=model(inputs)  # getting the outputs
  _, pred=torch.max(outputs, 1)
  nsamples+=labels.size(0)
  ncorrect+=(pred==labels).sum().item()  # getting the correct number of sampels
  for l, p in zip(labels,pred):
    cm[l.long(), p.long()] += 1  # adding values to confusion matrix

print("Accuracy on test data=",100*ncorrect/nsamples)
print("Confusion matrix on test data:")
print(cm)
# Out:
# Accuracy on test data= 67.1875
# Confusion matrix on test data:
# tensor([[ 32.,  13.,   5.,  11.,   0.],
#         [  1.,  54.,   3.,  10.,   0.],
#         [  4.,  12.,  36.,  18.,   8.],
#         [  3.,  11.,   4., 118.,   3.],
#         [  0.,   3.,   7.,  10.,  18.]])

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
df_cm=np.array(cm)
df_cm = pd.DataFrame(df_cm, index = na_class, columns = na_class)
plt.figure(figsize = (10,7))
sn.heatmap(df_cm, annot=True)
plt.show()

# %%
per_class_a=cm.diag()/cm.sum(axis=1)
# print(per_class_a)
for i in range(5):
  print(f"Accuracy of {na_class[i]} = {per_class_a[i]*100}")
# Out:
# Accuracy of comrav = 52.459014892578125
# Accuracy of houspa = 79.4117660522461
# Accuracy of houwre = 46.153846740722656
# Accuracy of redcro = 84.89208984375
# Accuracy of sonspa = 47.36842346191406

# %%
import numpy as np
def get_f1_score(confusion_matrix, i):
    TP = 0
    FP = 0
    TN = 0
    FN = 0
    for j in range(len(confusion_matrix)):
        if (i == j):
            TP += confusion_matrix[i][j]
            tmp = np.delete(confusion_matrix, i, 0)
            tmp = np.delete(tmp, j, 1)
            TN += np.sum(tmp)
        else:
            if (confusion_matrix[i][j] != 0):
                FN += confusion_matrix[i][j]
            if (confusion_matrix[j][i] != 0):
                FP += confusion_matrix[j][i]
    recall = TP / (FN + TP)
    precision = TP / (TP + FP)
    f1_score = 2 * 1/(1/recall + 1/precision)
    
    return f1_score

# %%
f1s=0
for i in range(5):
  f1=get_f1_score(np.array(cm),i)
  print(f"F1 of {na_class[i]} = {f1}")
  f1s+=f1
print("Average F1 score=", f1s/5)
# Out:
# F1 of comrav = 0.6336633663366337
# F1 of houspa = 0.6708074534161491
# F1 of houwre = 0.5413533834586467
# F1 of redcro = 0.7712418300653594
# F1 of sonspa = 0.5373134328358209
# Average F1 score= 0.6308758932225219
